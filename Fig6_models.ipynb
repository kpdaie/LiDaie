# %%
# %matplotlib inline
import sys
sys.path.append('./fig6')
from Fig6_models import modular_attractor_model1

# %%
trial_type = 1
stim_type = 0
modular_attractor_model1(trial_type,stim_type)

# %%
trial_type = 1
stim_type = 1
modular_attractor_model1(trial_type,stim_type)
modular_attractor_model1(trial_type,0)

# %%
trial_type = 1
stim_type = 2
modular_attractor_model1(trial_type,stim_type)
modular_attractor_model1(trial_type,0)

# %%
trial_type = 1
stim_type = 3
modular_attractor_model1(trial_type,stim_type)
modular_attractor_model1(trial_type,0)

# %%
# %matplotlib inline
import sys
sys.path.append('./fig6')
from Fig6_models import modular_integrator_model

# %%
stim_type = 1
modular_integrator_model(1)

# %%
execfile("modular_rnn_function.py")
# Out:
# running modular_rnn

# %%
M
# Out:
# array([[  3.45532186e-01,  -7.54341721e-04,  -3.61675714e-04, ...,
#           6.22827285e-03,   7.19477764e-03,   9.77022567e-02],
#        [  2.05741982e-02,  -7.54341721e-04,  -3.61675714e-04, ...,
#           6.22827285e-03,   1.43284234e-01,   1.49405961e-02],
#        [ -4.19191364e-01,  -1.78511384e-01,  -3.61675714e-04, ...,
#           6.22827285e-03,   7.19477764e-03,   1.49405961e-02],
#        ...,
#        [  6.45657880e-03,   7.07066304e-03,   6.89113029e-03, ...,
#           1.40098100e-03,  -9.45393801e-04,  -2.63971854e-03],
#        [  6.45657880e-03,   7.07066304e-03,   6.89113029e-03, ...,
#           1.40098100e-03,  -9.45393801e-04,  -2.63971854e-03],
#        [  6.45657880e-03,   7.07066304e-03,   6.89113029e-03, ...,
#           1.40098100e-03,  -9.45393801e-04,  -2.63971854e-03]])

# %%
plt.plot(Z[:,4,0,[0,1,2]])
