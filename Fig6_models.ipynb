# %% [markdown]
# # Figure 6 Models

# %%
# %matplotlib inline
import sys
sys.path.append('./fig6')
import matplotlib.pyplot as plt
from Fig6_models import modular_attractor_model
from Fig6_models import modular_integrator_model
from Fig6_models import modular_rnn_model

# %% [markdown]
# ## Figure 6b Modular attractor model
# <br\> stim_type = 0, for no perturbation <br\> stim_type = 1, for ipsilateral photoinhibition <br\> stim_type = 2, for contralateral photoinhibition <br\> stim_type = 3, for bilateral photoinhibition

# %%
plt.figure(num = 1,figsize = (8,2))
trial_type = 1;stim_type = 1
modular_attractor_model(trial_type,stim_type)
modular_attractor_model(trial_type,0)

# %% [markdown]
# ## Figure 6c Modular integrator model

# %%
stim_type = 1
modular_integrator_model(0);modular_integrator_model(stim_type)

# %% [markdown]
# ## Figure 6d Modular rnn model
# <br\> this will train a random rnn to be robust. n_loops is the number of training loops used

# %%
n_loops = 10;plt.figure(num = 3,figsize = (8,2))
modular_rnn_model(n_loops)
